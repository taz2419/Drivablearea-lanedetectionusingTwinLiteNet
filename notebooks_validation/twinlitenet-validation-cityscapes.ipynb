# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/cityscapes-validation/images/val/val181.png
# /kaggle/input/cityscapes-validation/images/val/val364.png
# /kaggle/input/cityscapes-validation/images/val/val414.png
# /kaggle/input/cityscapes-validation/images/val/val265.png
# /kaggle/input/cityscapes-validation/images/val/val203.png
# /kaggle/input/cityscapes-validation/images/val/val209.png
# /kaggle/input/cityscapes-validation/images/val/val279.png
# /kaggle/input/cityscapes-validation/images/val/val285.png
# /kaggle/input/cityscapes-validation/images/val/val126.png
# /kaggle/input/cityscapes-validation/images/val/val283.png
# /kaggle/input/cityscapes-validation/images/val/val239.png
# /kaggle/input/cityscapes-validation/images/val/val259.png
# /kaggle/input/cityscapes-validation/images/val/val210.png
# /kaggle/input/cityscapes-validation/images/val/val321.png
# /kaggle/input/cityscapes-validation/images/val/val278.png
# /kaggle/input/cityscapes-validation/images/val/val496.png
# /kaggle/input/cityscapes-validation/images/val/val207.png
# /kaggle/input/cityscapes-validation/images/val/val491.png
# /kaggle/input/cityscapes-validation/images/val/val121.png
# /kaggle/input/cityscapes-validation/images/val/val106.png
# /kaggle/input/cityscapes-validation/images/val/val125.png
# /kaggle/input/cityscapes-validation/images/val/val218.png
# /kaggle/input/cityscapes-validation/images/val/val14.png
# /kaggle/input/cityscapes-validation/images/val/val111.png
# /kaggle/input/cityscapes-validation/images/val/val36.png
# /kaggle/input/cityscapes-validation/images/val/val284.png
# /kaggle/input/cityscapes-validation/images/val/val361.png
# /kaggle/input/cityscapes-validation/images/val/val58.png
# /kaggle/input/cityscapes-validation/images/val/val419.png
# /kaggle/input/cityscapes-validation/images/val/val492.png
# /kaggle/input/cityscapes-validation/images/val/val386.png
# /kaggle/input/cityscapes-validation/images/val/val182.png
# /kaggle/input/cityscapes-validation/images/val/val171.png
# /kaggle/input/cityscapes-validation/images/val/val74.png
# /kaggle/input/cityscapes-validation/images/val/val139.png
# /kaggle/input/cityscapes-validation/images/val/val155.png
# /kaggle/input/cityscapes-validation/images/val/val176.png
# /kaggle/input/cityscapes-validation/images/val/val59.png
# /kaggle/input/cityscapes-validation/images/val/val269.png
# /kaggle/input/cityscapes-validation/images/val/val363.png
# /kaggle/input/cityscapes-validation/images/val/val441.png
# /kaggle/input/cityscapes-validation/images/val/val102.png
# /kaggle/input/cityscapes-validation/images/val/val95.png
# /kaggle/input/cityscapes-validation/images/val/val145.png
# /kaggle/input/cityscapes-validation/images/val/val337.png
# /kaggle/input/cityscapes-validation/images/val/val432.png
# /kaggle/input/cityscapes-validation/images/val/val192.png
# /kaggle/input/cityscapes-validation/images/val/val324.png
# /kaggle/input/cityscapes-validation/images/val/val465.png
# /kaggle/input/cityscapes-validation/images/val/val220.png
# /kaggle/input/cityscapes-validation/images/val/val99.png
# /kaggle/input/cityscapes-validation/images/val/val256.png
# /kaggle/input/cityscapes-validation/images/val/val439.png
# /kaggle/input/cityscapes-validation/images/val/val68.png
# /kaggle/input/cityscapes-validation/images/val/val258.png
# /kaggle/input/cityscapes-validation/images/val/val71.png
# /kaggle/input/cityscapes-validation/images/val/val183.png
# /kaggle/input/cityscapes-validation/images/val/val447.png
# /kaggle/input/cityscapes-validation/images/val/val483.png
# /kaggle/input/cityscapes-validation/images/val/val464.png
# /kaggle/input/cityscapes-validation/images/val/val318.png
# /kaggle/input/cityscapes-validation/images/val/val383.png
# /kaggle/input/cityscapes-validation/images/val/val107.png
# /kaggle/input/cityscapes-validation/images/val/val500.png
# /kaggle/input/cityscapes-validation/images/val/val307.png
# /kaggle/input/cityscapes-validation/images/val/val313.png
# /kaggle/input/cityscapes-validation/images/val/val417.png
# /kaggle/input/cityscapes-validation/images/val/val391.png
# /kaggle/input/cityscapes-validation/images/val/val468.png
# /kaggle/input/cityscapes-validation/images/val/val214.png
# /kaggle/input/cityscapes-validation/images/val/val88.png
# /kaggle/input/cityscapes-validation/images/val/val208.png
# /kaggle/input/cityscapes-validation/images/val/val56.png
# /kaggle/input/cityscapes-validation/images/val/val32.png
# /kaggle/input/cityscapes-validation/images/val/val444.png
# /kaggle/input/cityscapes-validation/images/val/val497.png
# /kaggle/input/cityscapes-validation/images/val/val268.png
# /kaggle/input/cityscapes-validation/images/val/val311.png
# /kaggle/input/cityscapes-validation/images/val/val165.png
# /kaggle/input/cityscapes-validation/images/val/val75.png
# /kaggle/input/cityscapes-validation/images/val/val67.png
# /kaggle/input/cityscapes-validation/images/val/val221.png
# /kaggle/input/cityscapes-validation/images/val/val270.png
# /kaggle/input/cityscapes-validation/images/val/val372.png
# /kaggle/input/cityscapes-validation/images/val/val294.png
# /kaggle/input/cityscapes-validation/images/val/val466.png
# /kaggle/input/cityscapes-validation/images/val/val277.png
# /kaggle/input/cityscapes-validation/images/val/val34.png
# /kaggle/input/cityscapes-validation/images/val/val119.png
# /kaggle/input/cityscapes-validation/images/val/val49.png
# /kaggle/input/cityscapes-validation/images/val/val61.png
# /kaggle/input/cityscapes-validation/images/val/val230.png
# /kaggle/input/cityscapes-validation/images/val/val348.png
# /kaggle/input/cityscapes-validation/images/val/val211.png
# /kaggle/input/cityscapes-validation/images/val/val486.png
# /kaggle/input/cityscapes-validation/images/val/val369.png
# /kaggle/input/cityscapes-validation/images/val/val272.png
# /kaggle/input/cityscapes-validation/images/val/val477.png
# /kaggle/input/cityscapes-validation/images/val/val275.png
# /kaggle/input/cityscapes-validation/images/val/val54.png
# /kaggle/input/cityscapes-validation/images/val/val437.png
# /kaggle/input/cityscapes-validation/images/val/val327.png
# /kaggle/input/cityscapes-validation/images/val/val460.png
# /kaggle/input/cityscapes-validation/images/val/val226.png
# /kaggle/input/cityscapes-validation/images/val/val303.png
# /kaggle/input/cityscapes-validation/images/val/val200.png
# /kaggle/input/cityscapes-validation/images/val/val201.png
# /kaggle/input/cityscapes-validation/images/val/val186.png
# /kaggle/input/cityscapes-validation/images/val/val70.png
# /kaggle/input/cityscapes-validation/images/val/val353.png
# /kaggle/input/cityscapes-validation/images/val/val354.png
# /kaggle/input/cityscapes-validation/images/val/val158.png
# /kaggle/input/cityscapes-validation/images/val/val412.png
# /kaggle/input/cityscapes-validation/images/val/val295.png
# /kaggle/input/cityscapes-validation/images/val/val325.png
# /kaggle/input/cityscapes-validation/images/val/val339.png
# /kaggle/input/cityscapes-validation/images/val/val315.png
# /kaggle/input/cityscapes-validation/images/val/val245.png
# /kaggle/input/cityscapes-validation/images/val/val46.png
# /kaggle/input/cityscapes-validation/images/val/val426.png
# /kaggle/input/cityscapes-validation/images/val/val143.png
# /kaggle/input/cityscapes-validation/images/val/val225.png
# /kaggle/input/cityscapes-validation/images/val/val229.png
# /kaggle/input/cityscapes-validation/images/val/val377.png
# /kaggle/input/cityscapes-validation/images/val/val458.png
# /kaggle/input/cityscapes-validation/images/val/val478.png
# /kaggle/input/cityscapes-validation/images/val/val159.png
# /kaggle/input/cityscapes-validation/images/val/val341.png
# /kaggle/input/cityscapes-validation/images/val/val280.png
# /kaggle/input/cityscapes-validation/images/val/val150.png
# /kaggle/input/cityscapes-validation/images/val/val43.png
# /kaggle/input/cityscapes-validation/images/val/val90.png
# /kaggle/input/cityscapes-validation/images/val/val13.png
# /kaggle/input/cityscapes-validation/images/val/val310.png
# /kaggle/input/cityscapes-validation/images/val/val246.png
# /kaggle/input/cityscapes-validation/images/val/val403.png
# /kaggle/input/cityscapes-validation/images/val/val81.png
# /kaggle/input/cityscapes-validation/images/val/val333.png
# /kaggle/input/cityscapes-validation/images/val/val44.png
# /kaggle/input/cityscapes-validation/images/val/val77.png
# /kaggle/input/cityscapes-validation/images/val/val332.png
# /kaggle/input/cityscapes-validation/images/val/val334.png
# /kaggle/input/cityscapes-validation/images/val/val471.png
# /kaggle/input/cityscapes-validation/images/val/val161.png
# /kaggle/input/cityscapes-validation/images/val/val91.png
# /kaggle/input/cityscapes-validation/images/val/val122.png
# /kaggle/input/cityscapes-validation/images/val/val57.png
# /kaggle/input/cityscapes-validation/images/val/val328.png
# /kaggle/input/cityscapes-validation/images/val/val443.png
# /kaggle/input/cityscapes-validation/images/val/val326.png
# /kaggle/input/cityscapes-validation/images/val/val300.png
# /kaggle/input/cityscapes-validation/images/val/val407.png
# /kaggle/input/cityscapes-validation/images/val/val379.png
# /kaggle/input/cityscapes-validation/images/val/val436.png
# /kaggle/input/cityscapes-validation/images/val/val331.png
# /kaggle/input/cityscapes-validation/images/val/val151.png
# /kaggle/input/cityscapes-validation/images/val/val223.png
# /kaggle/input/cityscapes-validation/images/val/val137.png
# /kaggle/input/cityscapes-validation/images/val/val83.png
# /kaggle/input/cityscapes-validation/images/val/val47.png
# /kaggle/input/cityscapes-validation/images/val/val305.png
# /kaggle/input/cityscapes-validation/images/val/val28.png
# /kaggle/input/cityscapes-validation/images/val/val194.png
# /kaggle/input/cityscapes-validation/images/val/val355.png
# /kaggle/input/cityscapes-validation/images/val/val184.png
# /kaggle/input/cityscapes-validation/images/val/val231.png
# /kaggle/input/cityscapes-validation/images/val/val234.png
# /kaggle/input/cityscapes-validation/images/val/val79.png
# /kaggle/input/cityscapes-validation/images/val/val396.png
# /kaggle/input/cityscapes-validation/images/val/val237.png
# /kaggle/input/cityscapes-validation/images/val/val296.png
# /kaggle/input/cityscapes-validation/images/val/val7.png
# /kaggle/input/cityscapes-validation/images/val/val282.png
# /kaggle/input/cityscapes-validation/images/val/val40.png
# /kaggle/input/cityscapes-validation/images/val/val42.png
# /kaggle/input/cityscapes-validation/images/val/val146.png
# /kaggle/input/cityscapes-validation/images/val/val413.png
# /kaggle/input/cityscapes-validation/images/val/val366.png
# /kaggle/input/cityscapes-validation/images/val/val136.png
# /kaggle/input/cityscapes-validation/images/val/val291.png
# /kaggle/input/cityscapes-validation/images/val/val255.png
# /kaggle/input/cityscapes-validation/images/val/val11.png
# /kaggle/input/cityscapes-validation/images/val/val190.png
# /kaggle/input/cityscapes-validation/images/val/val219.png
# /kaggle/input/cityscapes-validation/images/val/val257.png
# /kaggle/input/cityscapes-validation/images/val/val304.png
# /kaggle/input/cityscapes-validation/images/val/val235.png
# /kaggle/input/cityscapes-validation/images/val/val428.png
# /kaggle/input/cityscapes-validation/images/val/val429.png
# /kaggle/input/cityscapes-validation/images/val/val26.png
# /kaggle/input/cityscapes-validation/images/val/val233.png
# /kaggle/input/cityscapes-validation/images/val/val319.png
# /kaggle/input/cityscapes-validation/images/val/val445.png
# /kaggle/input/cityscapes-validation/images/val/val362.png
# /kaggle/input/cityscapes-validation/images/val/val342.png
# /kaggle/input/cityscapes-validation/images/val/val135.png
# /kaggle/input/cityscapes-validation/images/val/val261.png
# /kaggle/input/cityscapes-validation/images/val/val336.png
# /kaggle/input/cityscapes-validation/images/val/val108.png
# /kaggle/input/cityscapes-validation/images/val/val240.png
# /kaggle/input/cityscapes-validation/images/val/val117.png
# /kaggle/input/cityscapes-validation/images/val/val484.png
# /kaggle/input/cityscapes-validation/images/val/val185.png
# /kaggle/input/cityscapes-validation/images/val/val187.png
# /kaggle/input/cityscapes-validation/images/val/val343.png
# /kaggle/input/cityscapes-validation/images/val/val103.png
# /kaggle/input/cityscapes-validation/images/val/val389.png
# /kaggle/input/cityscapes-validation/images/val/val459.png
# /kaggle/input/cityscapes-validation/images/val/val347.png
# /kaggle/input/cityscapes-validation/images/val/val94.png
# /kaggle/input/cityscapes-validation/images/val/val12.png
# /kaggle/input/cityscapes-validation/images/val/val78.png
# /kaggle/input/cityscapes-validation/images/val/val224.png
# /kaggle/input/cityscapes-validation/images/val/val393.png
# /kaggle/input/cityscapes-validation/images/val/val180.png
# /kaggle/input/cityscapes-validation/images/val/val423.png
# /kaggle/input/cityscapes-validation/images/val/val215.png
# /kaggle/input/cityscapes-validation/images/val/val52.png
# /kaggle/input/cityscapes-validation/images/val/val213.png
# /kaggle/input/cityscapes-validation/images/val/val153.png
# /kaggle/input/cityscapes-validation/images/val/val179.png
# /kaggle/input/cityscapes-validation/images/val/val293.png
# /kaggle/input/cityscapes-validation/images/val/val384.png
# /kaggle/input/cityscapes-validation/images/val/val228.png
# /kaggle/input/cityscapes-validation/images/val/val1.png
# /kaggle/input/cityscapes-validation/images/val/val312.png
# /kaggle/input/cityscapes-validation/images/val/val448.png
# /kaggle/input/cityscapes-validation/images/val/val140.png
# /kaggle/input/cityscapes-validation/images/val/val17.png
# /kaggle/input/cityscapes-validation/images/val/val404.png
# /kaggle/input/cityscapes-validation/images/val/val387.png
# /kaggle/input/cityscapes-validation/images/val/val29.png
# /kaggle/input/cityscapes-validation/images/val/val30.png
# /kaggle/input/cityscapes-validation/images/val/val338.png
# /kaggle/input/cityscapes-validation/images/val/val371.png
# /kaggle/input/cityscapes-validation/images/val/val131.png
# /kaggle/input/cityscapes-validation/images/val/val167.png
# /kaggle/input/cityscapes-validation/images/val/val415.png
# /kaggle/input/cityscapes-validation/images/val/val382.png
# /kaggle/input/cityscapes-validation/images/val/val455.png
# /kaggle/input/cityscapes-validation/images/val/val178.png
# /kaggle/input/cityscapes-validation/images/val/val299.png
# /kaggle/input/cityscapes-validation/images/val/val263.png
# /kaggle/input/cityscapes-validation/images/val/val55.png
# /kaggle/input/cityscapes-validation/images/val/val317.png
# /kaggle/input/cityscapes-validation/images/val/val112.png
# /kaggle/input/cityscapes-validation/images/val/val18.png
# /kaggle/input/cityscapes-validation/images/val/val20.png
# /kaggle/input/cityscapes-validation/images/val/val197.png
# /kaggle/input/cityscapes-validation/images/val/val368.png
# /kaggle/input/cityscapes-validation/images/val/val435.png
# /kaggle/input/cityscapes-validation/images/val/val489.png
# /kaggle/input/cityscapes-validation/images/val/val410.png
# /kaggle/input/cityscapes-validation/images/val/val96.png
# /kaggle/input/cityscapes-validation/images/val/val405.png
# /kaggle/input/cityscapes-validation/images/val/val302.png
# /kaggle/input/cityscapes-validation/images/val/val482.png
# /kaggle/input/cityscapes-validation/images/val/val23.png
# /kaggle/input/cityscapes-validation/images/val/val418.png
# /kaggle/input/cityscapes-validation/images/val/val461.png
# /kaggle/input/cityscapes-validation/images/val/val367.png
# /kaggle/input/cityscapes-validation/images/val/val469.png
# /kaggle/input/cityscapes-validation/images/val/val38.png
# /kaggle/input/cityscapes-validation/images/val/val118.png
# /kaggle/input/cityscapes-validation/images/val/val451.png
# /kaggle/input/cityscapes-validation/images/val/val87.png
# /kaggle/input/cityscapes-validation/images/val/val262.png
# /kaggle/input/cityscapes-validation/images/val/val217.png
# /kaggle/input/cityscapes-validation/images/val/val273.png
# /kaggle/input/cityscapes-validation/images/val/val64.png
# /kaggle/input/cityscapes-validation/images/val/val346.png
# /kaggle/input/cityscapes-validation/images/val/val163.png
# /kaggle/input/cityscapes-validation/images/val/val129.png
# /kaggle/input/cityscapes-validation/images/val/val104.png
# /kaggle/input/cityscapes-validation/images/val/val340.png
# /kaggle/input/cityscapes-validation/images/val/val148.png
# /kaggle/input/cityscapes-validation/images/val/val314.png
# /kaggle/input/cityscapes-validation/images/val/val227.png
# /kaggle/input/cityscapes-validation/images/val/val86.png
# /kaggle/input/cityscapes-validation/images/val/val105.png
# /kaggle/input/cityscapes-validation/images/val/val24.png
# /kaggle/input/cityscapes-validation/images/val/val238.png
# /kaggle/input/cityscapes-validation/images/val/val15.png
# /kaggle/input/cityscapes-validation/images/val/val308.png
# /kaggle/input/cityscapes-validation/images/val/val144.png
# /kaggle/input/cityscapes-validation/images/val/val424.png
# /kaggle/input/cityscapes-validation/images/val/val127.png
# /kaggle/input/cityscapes-validation/images/val/val243.png
# /kaggle/input/cityscapes-validation/images/val/val21.png
# /kaggle/input/cityscapes-validation/images/val/val297.png
# /kaggle/input/cityscapes-validation/images/val/val378.png
# /kaggle/input/cityscapes-validation/images/val/val349.png
# /kaggle/input/cityscapes-validation/images/val/val480.png
# /kaggle/input/cityscapes-validation/images/val/val250.png
# /kaggle/input/cityscapes-validation/images/val/val309.png
# /kaggle/input/cityscapes-validation/images/val/val100.png
# /kaggle/input/cityscapes-validation/images/val/val290.png
# /kaggle/input/cityscapes-validation/images/val/val134.png
# /kaggle/input/cityscapes-validation/images/val/val154.png
# /kaggle/input/cityscapes-validation/images/val/val276.png
# /kaggle/input/cityscapes-validation/images/val/val472.png
# /kaggle/input/cityscapes-validation/images/val/val374.png
# /kaggle/input/cityscapes-validation/images/val/val481.png
# /kaggle/input/cityscapes-validation/images/val/val398.png
# /kaggle/input/cityscapes-validation/images/val/val132.png
# /kaggle/input/cityscapes-validation/images/val/val76.png
# /kaggle/input/cityscapes-validation/images/val/val253.png
# /kaggle/input/cityscapes-validation/images/val/val124.png
# /kaggle/input/cityscapes-validation/images/val/val10.png
# /kaggle/input/cityscapes-validation/images/val/val475.png
# /kaggle/input/cityscapes-validation/images/val/val493.png
# /kaggle/input/cityscapes-validation/images/val/val8.png
# /kaggle/input/cityscapes-validation/images/val/val420.png
# /kaggle/input/cityscapes-validation/images/val/val195.png
# /kaggle/input/cityscapes-validation/images/val/val330.png
# /kaggle/input/cityscapes-validation/images/val/val85.png
# /kaggle/input/cityscapes-validation/images/val/val449.png
# /kaggle/input/cityscapes-validation/images/val/val189.png
# /kaggle/input/cityscapes-validation/images/val/val380.png
# /kaggle/input/cityscapes-validation/images/val/val421.png
# /kaggle/input/cityscapes-validation/images/val/val388.png
# /kaggle/input/cityscapes-validation/images/val/val476.png
# /kaggle/input/cityscapes-validation/images/val/val462.png
# /kaggle/input/cityscapes-validation/images/val/val264.png
# /kaggle/input/cityscapes-validation/images/val/val138.png
# /kaggle/input/cityscapes-validation/images/val/val438.png
# /kaggle/input/cityscapes-validation/images/val/val375.png
# /kaggle/input/cityscapes-validation/images/val/val66.png
# /kaggle/input/cityscapes-validation/images/val/val281.png
# /kaggle/input/cityscapes-validation/images/val/val166.png
# /kaggle/input/cityscapes-validation/images/val/val499.png
# /kaggle/input/cityscapes-validation/images/val/val31.png
# /kaggle/input/cityscapes-validation/images/val/val39.png
# /kaggle/input/cityscapes-validation/images/val/val65.png
# /kaggle/input/cityscapes-validation/images/val/val160.png
# /kaggle/input/cityscapes-validation/images/val/val286.png
# /kaggle/input/cityscapes-validation/images/val/val485.png
# /kaggle/input/cityscapes-validation/images/val/val385.png
# /kaggle/input/cityscapes-validation/images/val/val350.png
# /kaggle/input/cityscapes-validation/images/val/val409.png
# /kaggle/input/cityscapes-validation/images/val/val470.png
# /kaggle/input/cityscapes-validation/images/val/val406.png
# /kaggle/input/cityscapes-validation/images/val/val359.png
# /kaggle/input/cityscapes-validation/images/val/val84.png
# /kaggle/input/cityscapes-validation/images/val/val157.png
# /kaggle/input/cityscapes-validation/images/val/val116.png
# /kaggle/input/cityscapes-validation/images/val/val120.png
# /kaggle/input/cityscapes-validation/images/val/val130.png
# /kaggle/input/cityscapes-validation/images/val/val170.png
# /kaggle/input/cityscapes-validation/images/val/val51.png
# /kaggle/input/cityscapes-validation/images/val/val222.png
# /kaggle/input/cityscapes-validation/images/val/val370.png
# /kaggle/input/cityscapes-validation/images/val/val373.png
# /kaggle/input/cityscapes-validation/images/val/val115.png
# /kaggle/input/cityscapes-validation/images/val/val400.png
# /kaggle/input/cityscapes-validation/images/val/val101.png
# /kaggle/input/cityscapes-validation/images/val/val411.png
# /kaggle/input/cityscapes-validation/images/val/val494.png
# /kaggle/input/cityscapes-validation/images/val/val241.png
# /kaggle/input/cityscapes-validation/images/val/val60.png
# /kaggle/input/cityscapes-validation/images/val/val329.png
# /kaggle/input/cityscapes-validation/images/val/val247.png
# /kaggle/input/cityscapes-validation/images/val/val446.png
# /kaggle/input/cityscapes-validation/images/val/val110.png
# /kaggle/input/cityscapes-validation/images/val/val33.png
# /kaggle/input/cityscapes-validation/images/val/val395.png
# /kaggle/input/cityscapes-validation/images/val/val72.png
# /kaggle/input/cityscapes-validation/images/val/val399.png
# /kaggle/input/cityscapes-validation/images/val/val41.png
# /kaggle/input/cityscapes-validation/images/val/val27.png
# /kaggle/input/cityscapes-validation/images/val/val453.png
# /kaggle/input/cityscapes-validation/images/val/val169.png
# /kaggle/input/cityscapes-validation/images/val/val123.png
# /kaggle/input/cityscapes-validation/images/val/val474.png
# /kaggle/input/cityscapes-validation/images/val/val113.png
# /kaggle/input/cityscapes-validation/images/val/val93.png
# /kaggle/input/cityscapes-validation/images/val/val48.png
# /kaggle/input/cityscapes-validation/images/val/val298.png
# /kaggle/input/cityscapes-validation/images/val/val390.png
# /kaggle/input/cityscapes-validation/images/val/val352.png
# /kaggle/input/cityscapes-validation/images/val/val193.png
# /kaggle/input/cityscapes-validation/images/val/val206.png
# /kaggle/input/cityscapes-validation/images/val/val358.png
# /kaggle/input/cityscapes-validation/images/val/val97.png
# /kaggle/input/cityscapes-validation/images/val/val288.png
# /kaggle/input/cityscapes-validation/images/val/val198.png
# /kaggle/input/cityscapes-validation/images/val/val357.png
# /kaggle/input/cityscapes-validation/images/val/val37.png
# /kaggle/input/cityscapes-validation/images/val/val164.png
# /kaggle/input/cityscapes-validation/images/val/val142.png
# /kaggle/input/cityscapes-validation/images/val/val301.png
# /kaggle/input/cityscapes-validation/images/val/val266.png
# /kaggle/input/cityscapes-validation/images/val/val212.png
# /kaggle/input/cityscapes-validation/images/val/val244.png
# /kaggle/input/cityscapes-validation/images/val/val177.png
# /kaggle/input/cityscapes-validation/images/val/val45.png
# /kaggle/input/cityscapes-validation/images/val/val394.png
# /kaggle/input/cityscapes-validation/images/val/val175.png
# /kaggle/input/cityscapes-validation/images/val/val323.png
# /kaggle/input/cityscapes-validation/images/val/val69.png
# /kaggle/input/cityscapes-validation/images/val/val463.png
# /kaggle/input/cityscapes-validation/images/val/val199.png
# /kaggle/input/cityscapes-validation/images/val/val479.png
# /kaggle/input/cityscapes-validation/images/val/val4.png
# /kaggle/input/cityscapes-validation/images/val/val249.png
# /kaggle/input/cityscapes-validation/images/val/val442.png
# /kaggle/input/cityscapes-validation/images/val/val63.png
# /kaggle/input/cityscapes-validation/images/val/val408.png
# /kaggle/input/cityscapes-validation/images/val/val320.png
# /kaggle/input/cityscapes-validation/images/val/val73.png
# /kaggle/input/cityscapes-validation/images/val/val376.png
# /kaggle/input/cityscapes-validation/images/val/val174.png
# /kaggle/input/cityscapes-validation/images/val/val316.png
# /kaggle/input/cityscapes-validation/images/val/val351.png
# /kaggle/input/cityscapes-validation/images/val/val456.png
# /kaggle/input/cityscapes-validation/images/val/val6.png
# /kaggle/input/cityscapes-validation/images/val/val430.png
# /kaggle/input/cityscapes-validation/images/val/val173.png
# /kaggle/input/cityscapes-validation/images/val/val3.png
# /kaggle/input/cityscapes-validation/images/val/val306.png
# /kaggle/input/cityscapes-validation/images/val/val248.png
# /kaggle/input/cityscapes-validation/images/val/val260.png
# /kaggle/input/cityscapes-validation/images/val/val53.png
# /kaggle/input/cityscapes-validation/images/val/val425.png
# /kaggle/input/cityscapes-validation/images/val/val488.png
# /kaggle/input/cityscapes-validation/images/val/val16.png
# /kaggle/input/cityscapes-validation/images/val/val397.png
# /kaggle/input/cityscapes-validation/images/val/val467.png
# /kaggle/input/cityscapes-validation/images/val/val25.png
# /kaggle/input/cityscapes-validation/images/val/val149.png
# /kaggle/input/cityscapes-validation/images/val/val232.png
# /kaggle/input/cityscapes-validation/images/val/val35.png
# /kaggle/input/cityscapes-validation/images/val/val365.png
# /kaggle/input/cityscapes-validation/images/val/val452.png
# /kaggle/input/cityscapes-validation/images/val/val80.png
# /kaggle/input/cityscapes-validation/images/val/val490.png
# /kaggle/input/cityscapes-validation/images/val/val292.png
# /kaggle/input/cityscapes-validation/images/val/val345.png
# /kaggle/input/cityscapes-validation/images/val/val252.png
# /kaggle/input/cityscapes-validation/images/val/val356.png
# /kaggle/input/cityscapes-validation/images/val/val433.png
# /kaggle/input/cityscapes-validation/images/val/val422.png
# /kaggle/input/cityscapes-validation/images/val/val402.png
# /kaggle/input/cityscapes-validation/images/val/val133.png
# /kaggle/input/cityscapes-validation/images/val/val236.png
# /kaggle/input/cityscapes-validation/images/val/val254.png
# /kaggle/input/cityscapes-validation/images/val/val289.png
# /kaggle/input/cityscapes-validation/images/val/val360.png
# /kaggle/input/cityscapes-validation/images/val/val196.png
# /kaggle/input/cityscapes-validation/images/val/val267.png
# /kaggle/input/cityscapes-validation/images/val/val172.png
# /kaggle/input/cityscapes-validation/images/val/val98.png
# /kaggle/input/cityscapes-validation/images/val/val128.png
# /kaggle/input/cityscapes-validation/images/val/val147.png
# /kaggle/input/cityscapes-validation/images/val/val392.png
# /kaggle/input/cityscapes-validation/images/val/val473.png
# /kaggle/input/cityscapes-validation/images/val/val2.png
# /kaggle/input/cityscapes-validation/images/val/val271.png
# /kaggle/input/cityscapes-validation/images/val/val89.png
# /kaggle/input/cityscapes-validation/images/val/val9.png
# /kaggle/input/cityscapes-validation/images/val/val141.png
# /kaggle/input/cityscapes-validation/images/val/val168.png
# /kaggle/input/cityscapes-validation/images/val/val109.png
# /kaggle/input/cityscapes-validation/images/val/val401.png
# /kaggle/input/cityscapes-validation/images/val/val114.png
# /kaggle/input/cityscapes-validation/images/val/val162.png
# /kaggle/input/cityscapes-validation/images/val/val62.png
# /kaggle/input/cityscapes-validation/images/val/val204.png
# /kaggle/input/cityscapes-validation/images/val/val344.png
# /kaggle/input/cityscapes-validation/images/val/val156.png
# /kaggle/input/cityscapes-validation/images/val/val487.png
# /kaggle/input/cityscapes-validation/images/val/val381.png
# /kaggle/input/cityscapes-validation/images/val/val205.png
# /kaggle/input/cityscapes-validation/images/val/val495.png
# /kaggle/input/cityscapes-validation/images/val/val498.png
# /kaggle/input/cityscapes-validation/images/val/val434.png
# /kaggle/input/cityscapes-validation/images/val/val431.png
# /kaggle/input/cityscapes-validation/images/val/val5.png
# /kaggle/input/cityscapes-validation/images/val/val440.png
# /kaggle/input/cityscapes-validation/images/val/val242.png
# /kaggle/input/cityscapes-validation/images/val/val216.png
# /kaggle/input/cityscapes-validation/images/val/val191.png
# /kaggle/input/cityscapes-validation/images/val/val454.png
# /kaggle/input/cityscapes-validation/images/val/val335.png
# /kaggle/input/cityscapes-validation/images/val/val274.png
# /kaggle/input/cityscapes-validation/images/val/val322.png
# /kaggle/input/cityscapes-validation/images/val/val251.png
# /kaggle/input/cityscapes-validation/images/val/val457.png
# /kaggle/input/cityscapes-validation/images/val/val450.png
# /kaggle/input/cityscapes-validation/images/val/val416.png
# /kaggle/input/cityscapes-validation/images/val/val287.png
# /kaggle/input/cityscapes-validation/images/val/val92.png
# /kaggle/input/cityscapes-validation/images/val/val50.png
# /kaggle/input/cityscapes-validation/images/val/val82.png
# /kaggle/input/cityscapes-validation/images/val/val22.png
# /kaggle/input/cityscapes-validation/images/val/val202.png
# /kaggle/input/cityscapes-validation/images/val/val188.png
# /kaggle/input/cityscapes-validation/images/val/val427.png
# /kaggle/input/cityscapes-validation/images/val/val152.png
# /kaggle/input/cityscapes-validation/images/val/val19.png
# /kaggle/input/cityscapes-validation/segments/val/val181.png
# /kaggle/input/cityscapes-validation/segments/val/val364.png
# /kaggle/input/cityscapes-validation/segments/val/val414.png
# /kaggle/input/cityscapes-validation/segments/val/val265.png
# /kaggle/input/cityscapes-validation/segments/val/val203.png
# /kaggle/input/cityscapes-validation/segments/val/val209.png
# /kaggle/input/cityscapes-validation/segments/val/val279.png
# /kaggle/input/cityscapes-validation/segments/val/val285.png
# /kaggle/input/cityscapes-validation/segments/val/val126.png
# /kaggle/input/cityscapes-validation/segments/val/val283.png
# /kaggle/input/cityscapes-validation/segments/val/val239.png
# /kaggle/input/cityscapes-validation/segments/val/val259.png
# /kaggle/input/cityscapes-validation/segments/val/val210.png
# /kaggle/input/cityscapes-validation/segments/val/val321.png
# /kaggle/input/cityscapes-validation/segments/val/val278.png
# /kaggle/input/cityscapes-validation/segments/val/val496.png
# /kaggle/input/cityscapes-validation/segments/val/val207.png
# /kaggle/input/cityscapes-validation/segments/val/val491.png
# /kaggle/input/cityscapes-validation/segments/val/val121.png
# /kaggle/input/cityscapes-validation/segments/val/val106.png
# /kaggle/input/cityscapes-validation/segments/val/val125.png
# /kaggle/input/cityscapes-validation/segments/val/val218.png
# /kaggle/input/cityscapes-validation/segments/val/val14.png
# /kaggle/input/cityscapes-validation/segments/val/val111.png
# /kaggle/input/cityscapes-validation/segments/val/val36.png
# /kaggle/input/cityscapes-validation/segments/val/val284.png
# /kaggle/input/cityscapes-validation/segments/val/val361.png
# /kaggle/input/cityscapes-validation/segments/val/val58.png
# /kaggle/input/cityscapes-validation/segments/val/val419.png
# /kaggle/input/cityscapes-validation/segments/val/val492.png
# /kaggle/input/cityscapes-validation/segments/val/val386.png
# /kaggle/input/cityscapes-validation/segments/val/val182.png
# /kaggle/input/cityscapes-validation/segments/val/val171.png
# /kaggle/input/cityscapes-validation/segments/val/val74.png
# /kaggle/input/cityscapes-validation/segments/val/val139.png
# /kaggle/input/cityscapes-validation/segments/val/val155.png
# /kaggle/input/cityscapes-validation/segments/val/val176.png
# /kaggle/input/cityscapes-validation/segments/val/val59.png
# /kaggle/input/cityscapes-validation/segments/val/val269.png
# /kaggle/input/cityscapes-validation/segments/val/val363.png
# /kaggle/input/cityscapes-validation/segments/val/val441.png
# /kaggle/input/cityscapes-validation/segments/val/val102.png
# /kaggle/input/cityscapes-validation/segments/val/val95.png
# /kaggle/input/cityscapes-validation/segments/val/val145.png
# /kaggle/input/cityscapes-validation/segments/val/val337.png
# /kaggle/input/cityscapes-validation/segments/val/val432.png
# /kaggle/input/cityscapes-validation/segments/val/val192.png
# /kaggle/input/cityscapes-validation/segments/val/val324.png
# /kaggle/input/cityscapes-validation/segments/val/val465.png
# /kaggle/input/cityscapes-validation/segments/val/val220.png
# /kaggle/input/cityscapes-validation/segments/val/val99.png
# /kaggle/input/cityscapes-validation/segments/val/val256.png
# /kaggle/input/cityscapes-validation/segments/val/val439.png
# /kaggle/input/cityscapes-validation/segments/val/val68.png
# /kaggle/input/cityscapes-validation/segments/val/val258.png
# /kaggle/input/cityscapes-validation/segments/val/val71.png
# /kaggle/input/cityscapes-validation/segments/val/val183.png
# /kaggle/input/cityscapes-validation/segments/val/val447.png
# /kaggle/input/cityscapes-validation/segments/val/val483.png
# /kaggle/input/cityscapes-validation/segments/val/val464.png
# /kaggle/input/cityscapes-validation/segments/val/val318.png
# /kaggle/input/cityscapes-validation/segments/val/val383.png
# /kaggle/input/cityscapes-validation/segments/val/val107.png
# /kaggle/input/cityscapes-validation/segments/val/val500.png
# /kaggle/input/cityscapes-validation/segments/val/val307.png
# /kaggle/input/cityscapes-validation/segments/val/val313.png
# /kaggle/input/cityscapes-validation/segments/val/val417.png
# /kaggle/input/cityscapes-validation/segments/val/val391.png
# /kaggle/input/cityscapes-validation/segments/val/val468.png
# /kaggle/input/cityscapes-validation/segments/val/val214.png
# /kaggle/input/cityscapes-validation/segments/val/val88.png
# /kaggle/input/cityscapes-validation/segments/val/val208.png
# /kaggle/input/cityscapes-validation/segments/val/val56.png
# /kaggle/input/cityscapes-validation/segments/val/val32.png
# /kaggle/input/cityscapes-validation/segments/val/val444.png
# /kaggle/input/cityscapes-validation/segments/val/val497.png
# /kaggle/input/cityscapes-validation/segments/val/val268.png
# /kaggle/input/cityscapes-validation/segments/val/val311.png
# /kaggle/input/cityscapes-validation/segments/val/val165.png
# /kaggle/input/cityscapes-validation/segments/val/val75.png
# /kaggle/input/cityscapes-validation/segments/val/val67.png
# /kaggle/input/cityscapes-validation/segments/val/val221.png
# /kaggle/input/cityscapes-validation/segments/val/val270.png
# /kaggle/input/cityscapes-validation/segments/val/val372.png
# /kaggle/input/cityscapes-validation/segments/val/val294.png
# /kaggle/input/cityscapes-validation/segments/val/val466.png
# /kaggle/input/cityscapes-validation/segments/val/val277.png
# /kaggle/input/cityscapes-validation/segments/val/val34.png
# /kaggle/input/cityscapes-validation/segments/val/val119.png
# /kaggle/input/cityscapes-validation/segments/val/val49.png
# /kaggle/input/cityscapes-validation/segments/val/val61.png
# /kaggle/input/cityscapes-validation/segments/val/val230.png
# /kaggle/input/cityscapes-validation/segments/val/val348.png
# /kaggle/input/cityscapes-validation/segments/val/val211.png
# /kaggle/input/cityscapes-validation/segments/val/val486.png
# /kaggle/input/cityscapes-validation/segments/val/val369.png
# /kaggle/input/cityscapes-validation/segments/val/val272.png
# /kaggle/input/cityscapes-validation/segments/val/val477.png
# /kaggle/input/cityscapes-validation/segments/val/val275.png
# /kaggle/input/cityscapes-validation/segments/val/val54.png
# /kaggle/input/cityscapes-validation/segments/val/val437.png
# /kaggle/input/cityscapes-validation/segments/val/val327.png
# /kaggle/input/cityscapes-validation/segments/val/val460.png
# /kaggle/input/cityscapes-validation/segments/val/val226.png
# /kaggle/input/cityscapes-validation/segments/val/val303.png
# /kaggle/input/cityscapes-validation/segments/val/val200.png
# /kaggle/input/cityscapes-validation/segments/val/val201.png
# /kaggle/input/cityscapes-validation/segments/val/val186.png
# /kaggle/input/cityscapes-validation/segments/val/val70.png
# /kaggle/input/cityscapes-validation/segments/val/val353.png
# /kaggle/input/cityscapes-validation/segments/val/val354.png
# /kaggle/input/cityscapes-validation/segments/val/val158.png
# /kaggle/input/cityscapes-validation/segments/val/val412.png
# /kaggle/input/cityscapes-validation/segments/val/val295.png
# /kaggle/input/cityscapes-validation/segments/val/val325.png
# /kaggle/input/cityscapes-validation/segments/val/val339.png
# /kaggle/input/cityscapes-validation/segments/val/val315.png
# /kaggle/input/cityscapes-validation/segments/val/val245.png
# /kaggle/input/cityscapes-validation/segments/val/val46.png
# /kaggle/input/cityscapes-validation/segments/val/val426.png
# /kaggle/input/cityscapes-validation/segments/val/val143.png
# /kaggle/input/cityscapes-validation/segments/val/val225.png
# /kaggle/input/cityscapes-validation/segments/val/val229.png
# /kaggle/input/cityscapes-validation/segments/val/val377.png
# /kaggle/input/cityscapes-validation/segments/val/val458.png
# /kaggle/input/cityscapes-validation/segments/val/val478.png
# /kaggle/input/cityscapes-validation/segments/val/val159.png
# /kaggle/input/cityscapes-validation/segments/val/val341.png
# /kaggle/input/cityscapes-validation/segments/val/val280.png
# /kaggle/input/cityscapes-validation/segments/val/val150.png
# /kaggle/input/cityscapes-validation/segments/val/val43.png
# /kaggle/input/cityscapes-validation/segments/val/val90.png
# /kaggle/input/cityscapes-validation/segments/val/val13.png
# /kaggle/input/cityscapes-validation/segments/val/val310.png
# /kaggle/input/cityscapes-validation/segments/val/val246.png
# /kaggle/input/cityscapes-validation/segments/val/val403.png
# /kaggle/input/cityscapes-validation/segments/val/val81.png
# /kaggle/input/cityscapes-validation/segments/val/val333.png
# /kaggle/input/cityscapes-validation/segments/val/val44.png
# /kaggle/input/cityscapes-validation/segments/val/val77.png
# /kaggle/input/cityscapes-validation/segments/val/val332.png
# /kaggle/input/cityscapes-validation/segments/val/val334.png
# /kaggle/input/cityscapes-validation/segments/val/val471.png
# /kaggle/input/cityscapes-validation/segments/val/val161.png
# /kaggle/input/cityscapes-validation/segments/val/val91.png
# /kaggle/input/cityscapes-validation/segments/val/val122.png
# /kaggle/input/cityscapes-validation/segments/val/val57.png
# /kaggle/input/cityscapes-validation/segments/val/val328.png
# /kaggle/input/cityscapes-validation/segments/val/val443.png
# /kaggle/input/cityscapes-validation/segments/val/val326.png
# /kaggle/input/cityscapes-validation/segments/val/val300.png
# /kaggle/input/cityscapes-validation/segments/val/val407.png
# /kaggle/input/cityscapes-validation/segments/val/val379.png
# /kaggle/input/cityscapes-validation/segments/val/val436.png
# /kaggle/input/cityscapes-validation/segments/val/val331.png
# /kaggle/input/cityscapes-validation/segments/val/val151.png
# /kaggle/input/cityscapes-validation/segments/val/val223.png
# /kaggle/input/cityscapes-validation/segments/val/val137.png
# /kaggle/input/cityscapes-validation/segments/val/val83.png
# /kaggle/input/cityscapes-validation/segments/val/val47.png
# /kaggle/input/cityscapes-validation/segments/val/val305.png
# /kaggle/input/cityscapes-validation/segments/val/val28.png
# /kaggle/input/cityscapes-validation/segments/val/val194.png
# /kaggle/input/cityscapes-validation/segments/val/val355.png
# /kaggle/input/cityscapes-validation/segments/val/val184.png
# /kaggle/input/cityscapes-validation/segments/val/val231.png
# /kaggle/input/cityscapes-validation/segments/val/val234.png
# /kaggle/input/cityscapes-validation/segments/val/val79.png
# /kaggle/input/cityscapes-validation/segments/val/val396.png
# /kaggle/input/cityscapes-validation/segments/val/val237.png
# /kaggle/input/cityscapes-validation/segments/val/val296.png
# /kaggle/input/cityscapes-validation/segments/val/val7.png
# /kaggle/input/cityscapes-validation/segments/val/val282.png
# /kaggle/input/cityscapes-validation/segments/val/val40.png
# /kaggle/input/cityscapes-validation/segments/val/val42.png
# /kaggle/input/cityscapes-validation/segments/val/val146.png
# /kaggle/input/cityscapes-validation/segments/val/val413.png
# /kaggle/input/cityscapes-validation/segments/val/val366.png
# /kaggle/input/cityscapes-validation/segments/val/val136.png
# /kaggle/input/cityscapes-validation/segments/val/val291.png
# /kaggle/input/cityscapes-validation/segments/val/val255.png
# /kaggle/input/cityscapes-validation/segments/val/val11.png
# /kaggle/input/cityscapes-validation/segments/val/val190.png
# /kaggle/input/cityscapes-validation/segments/val/val219.png
# /kaggle/input/cityscapes-validation/segments/val/val257.png
# /kaggle/input/cityscapes-validation/segments/val/val304.png
# /kaggle/input/cityscapes-validation/segments/val/val235.png
# /kaggle/input/cityscapes-validation/segments/val/val428.png
# /kaggle/input/cityscapes-validation/segments/val/val429.png
# /kaggle/input/cityscapes-validation/segments/val/val26.png
# /kaggle/input/cityscapes-validation/segments/val/val233.png
# /kaggle/input/cityscapes-validation/segments/val/val319.png
# /kaggle/input/cityscapes-validation/segments/val/val445.png
# /kaggle/input/cityscapes-validation/segments/val/val362.png
# /kaggle/input/cityscapes-validation/segments/val/val342.png
# /kaggle/input/cityscapes-validation/segments/val/val135.png
# /kaggle/input/cityscapes-validation/segments/val/val261.png
# /kaggle/input/cityscapes-validation/segments/val/val336.png
# /kaggle/input/cityscapes-validation/segments/val/val108.png
# /kaggle/input/cityscapes-validation/segments/val/val240.png
# /kaggle/input/cityscapes-validation/segments/val/val117.png
# /kaggle/input/cityscapes-validation/segments/val/val484.png
# /kaggle/input/cityscapes-validation/segments/val/val185.png
# /kaggle/input/cityscapes-validation/segments/val/val187.png
# /kaggle/input/cityscapes-validation/segments/val/val343.png
# /kaggle/input/cityscapes-validation/segments/val/val103.png
# /kaggle/input/cityscapes-validation/segments/val/val389.png
# /kaggle/input/cityscapes-validation/segments/val/val459.png
# /kaggle/input/cityscapes-validation/segments/val/val347.png
# /kaggle/input/cityscapes-validation/segments/val/val94.png
# /kaggle/input/cityscapes-validation/segments/val/val12.png
# /kaggle/input/cityscapes-validation/segments/val/val78.png
# /kaggle/input/cityscapes-validation/segments/val/val224.png
# /kaggle/input/cityscapes-validation/segments/val/val393.png
# /kaggle/input/cityscapes-validation/segments/val/val180.png
# /kaggle/input/cityscapes-validation/segments/val/val423.png
# /kaggle/input/cityscapes-validation/segments/val/val215.png
# /kaggle/input/cityscapes-validation/segments/val/val52.png
# /kaggle/input/cityscapes-validation/segments/val/val213.png
# /kaggle/input/cityscapes-validation/segments/val/val153.png
# /kaggle/input/cityscapes-validation/segments/val/val179.png
# /kaggle/input/cityscapes-validation/segments/val/val293.png
# /kaggle/input/cityscapes-validation/segments/val/val384.png
# /kaggle/input/cityscapes-validation/segments/val/val228.png
# /kaggle/input/cityscapes-validation/segments/val/val1.png
# /kaggle/input/cityscapes-validation/segments/val/val312.png
# /kaggle/input/cityscapes-validation/segments/val/val448.png
# /kaggle/input/cityscapes-validation/segments/val/val140.png
# /kaggle/input/cityscapes-validation/segments/val/val17.png
# /kaggle/input/cityscapes-validation/segments/val/val404.png
# /kaggle/input/cityscapes-validation/segments/val/val387.png
# /kaggle/input/cityscapes-validation/segments/val/val29.png
# /kaggle/input/cityscapes-validation/segments/val/val30.png
# /kaggle/input/cityscapes-validation/segments/val/val338.png
# /kaggle/input/cityscapes-validation/segments/val/val371.png
# /kaggle/input/cityscapes-validation/segments/val/val131.png
# /kaggle/input/cityscapes-validation/segments/val/val167.png
# /kaggle/input/cityscapes-validation/segments/val/val415.png
# /kaggle/input/cityscapes-validation/segments/val/val382.png
# /kaggle/input/cityscapes-validation/segments/val/val455.png
# /kaggle/input/cityscapes-validation/segments/val/val178.png
# /kaggle/input/cityscapes-validation/segments/val/val299.png
# /kaggle/input/cityscapes-validation/segments/val/val263.png
# /kaggle/input/cityscapes-validation/segments/val/val55.png
# /kaggle/input/cityscapes-validation/segments/val/val317.png
# /kaggle/input/cityscapes-validation/segments/val/val112.png
# /kaggle/input/cityscapes-validation/segments/val/val18.png
# /kaggle/input/cityscapes-validation/segments/val/val20.png
# /kaggle/input/cityscapes-validation/segments/val/val197.png
# /kaggle/input/cityscapes-validation/segments/val/val368.png
# /kaggle/input/cityscapes-validation/segments/val/val435.png
# /kaggle/input/cityscapes-validation/segments/val/val489.png
# /kaggle/input/cityscapes-validation/segments/val/val410.png
# /kaggle/input/cityscapes-validation/segments/val/val96.png
# /kaggle/input/cityscapes-validation/segments/val/val405.png
# /kaggle/input/cityscapes-validation/segments/val/val302.png
# /kaggle/input/cityscapes-validation/segments/val/val482.png
# /kaggle/input/cityscapes-validation/segments/val/val23.png
# /kaggle/input/cityscapes-validation/segments/val/val418.png
# /kaggle/input/cityscapes-validation/segments/val/val461.png
# /kaggle/input/cityscapes-validation/segments/val/val367.png
# /kaggle/input/cityscapes-validation/segments/val/val469.png
# /kaggle/input/cityscapes-validation/segments/val/val38.png
# /kaggle/input/cityscapes-validation/segments/val/val118.png
# /kaggle/input/cityscapes-validation/segments/val/val451.png
# /kaggle/input/cityscapes-validation/segments/val/val87.png
# /kaggle/input/cityscapes-validation/segments/val/val262.png
# /kaggle/input/cityscapes-validation/segments/val/val217.png
# /kaggle/input/cityscapes-validation/segments/val/val273.png
# /kaggle/input/cityscapes-validation/segments/val/val64.png
# /kaggle/input/cityscapes-validation/segments/val/val346.png
# /kaggle/input/cityscapes-validation/segments/val/val163.png
# /kaggle/input/cityscapes-validation/segments/val/val129.png
# /kaggle/input/cityscapes-validation/segments/val/val104.png
# /kaggle/input/cityscapes-validation/segments/val/val340.png
# /kaggle/input/cityscapes-validation/segments/val/val148.png
# /kaggle/input/cityscapes-validation/segments/val/val314.png
# /kaggle/input/cityscapes-validation/segments/val/val227.png
# /kaggle/input/cityscapes-validation/segments/val/val86.png
# /kaggle/input/cityscapes-validation/segments/val/val105.png
# /kaggle/input/cityscapes-validation/segments/val/val24.png
# /kaggle/input/cityscapes-validation/segments/val/val238.png
# /kaggle/input/cityscapes-validation/segments/val/val15.png
# /kaggle/input/cityscapes-validation/segments/val/val308.png
# /kaggle/input/cityscapes-validation/segments/val/val144.png
# /kaggle/input/cityscapes-validation/segments/val/val424.png
# /kaggle/input/cityscapes-validation/segments/val/val127.png
# /kaggle/input/cityscapes-validation/segments/val/val243.png
# /kaggle/input/cityscapes-validation/segments/val/val21.png
# /kaggle/input/cityscapes-validation/segments/val/val297.png
# /kaggle/input/cityscapes-validation/segments/val/val378.png
# /kaggle/input/cityscapes-validation/segments/val/val349.png
# /kaggle/input/cityscapes-validation/segments/val/val480.png
# /kaggle/input/cityscapes-validation/segments/val/val250.png
# /kaggle/input/cityscapes-validation/segments/val/val309.png
# /kaggle/input/cityscapes-validation/segments/val/val100.png
# /kaggle/input/cityscapes-validation/segments/val/val290.png
# /kaggle/input/cityscapes-validation/segments/val/val134.png
# /kaggle/input/cityscapes-validation/segments/val/val154.png
# /kaggle/input/cityscapes-validation/segments/val/val276.png
# /kaggle/input/cityscapes-validation/segments/val/val472.png
# /kaggle/input/cityscapes-validation/segments/val/val374.png
# /kaggle/input/cityscapes-validation/segments/val/val481.png
# /kaggle/input/cityscapes-validation/segments/val/val398.png
# /kaggle/input/cityscapes-validation/segments/val/val132.png
# /kaggle/input/cityscapes-validation/segments/val/val76.png
# /kaggle/input/cityscapes-validation/segments/val/val253.png
# /kaggle/input/cityscapes-validation/segments/val/val124.png
# /kaggle/input/cityscapes-validation/segments/val/val10.png
# /kaggle/input/cityscapes-validation/segments/val/val475.png
# /kaggle/input/cityscapes-validation/segments/val/val493.png
# /kaggle/input/cityscapes-validation/segments/val/val8.png
# /kaggle/input/cityscapes-validation/segments/val/val420.png
# /kaggle/input/cityscapes-validation/segments/val/val195.png
# /kaggle/input/cityscapes-validation/segments/val/val330.png
# /kaggle/input/cityscapes-validation/segments/val/val85.png
# /kaggle/input/cityscapes-validation/segments/val/val449.png
# /kaggle/input/cityscapes-validation/segments/val/val189.png
# /kaggle/input/cityscapes-validation/segments/val/val380.png
# /kaggle/input/cityscapes-validation/segments/val/val421.png
# /kaggle/input/cityscapes-validation/segments/val/val388.png
# /kaggle/input/cityscapes-validation/segments/val/val476.png
# /kaggle/input/cityscapes-validation/segments/val/val462.png
# /kaggle/input/cityscapes-validation/segments/val/val264.png
# /kaggle/input/cityscapes-validation/segments/val/val138.png
# /kaggle/input/cityscapes-validation/segments/val/val438.png
# /kaggle/input/cityscapes-validation/segments/val/val375.png
# /kaggle/input/cityscapes-validation/segments/val/val66.png
# /kaggle/input/cityscapes-validation/segments/val/val281.png
# /kaggle/input/cityscapes-validation/segments/val/val166.png
# /kaggle/input/cityscapes-validation/segments/val/val499.png
# /kaggle/input/cityscapes-validation/segments/val/val31.png
# /kaggle/input/cityscapes-validation/segments/val/val39.png
# /kaggle/input/cityscapes-validation/segments/val/val65.png
# /kaggle/input/cityscapes-validation/segments/val/val160.png
# /kaggle/input/cityscapes-validation/segments/val/val286.png
# /kaggle/input/cityscapes-validation/segments/val/val485.png
# /kaggle/input/cityscapes-validation/segments/val/val385.png
# /kaggle/input/cityscapes-validation/segments/val/val350.png
# /kaggle/input/cityscapes-validation/segments/val/val409.png
# /kaggle/input/cityscapes-validation/segments/val/val470.png
# /kaggle/input/cityscapes-validation/segments/val/val406.png
# /kaggle/input/cityscapes-validation/segments/val/val359.png
# /kaggle/input/cityscapes-validation/segments/val/val84.png
# /kaggle/input/cityscapes-validation/segments/val/val157.png
# /kaggle/input/cityscapes-validation/segments/val/val116.png
# /kaggle/input/cityscapes-validation/segments/val/val120.png
# /kaggle/input/cityscapes-validation/segments/val/val130.png
# /kaggle/input/cityscapes-validation/segments/val/val170.png
# /kaggle/input/cityscapes-validation/segments/val/val51.png
# /kaggle/input/cityscapes-validation/segments/val/val222.png
# /kaggle/input/cityscapes-validation/segments/val/val370.png
# /kaggle/input/cityscapes-validation/segments/val/val373.png
# /kaggle/input/cityscapes-validation/segments/val/val115.png
# /kaggle/input/cityscapes-validation/segments/val/val400.png
# /kaggle/input/cityscapes-validation/segments/val/val101.png
# /kaggle/input/cityscapes-validation/segments/val/val411.png
# /kaggle/input/cityscapes-validation/segments/val/val494.png
# /kaggle/input/cityscapes-validation/segments/val/val241.png
# /kaggle/input/cityscapes-validation/segments/val/val60.png
# /kaggle/input/cityscapes-validation/segments/val/val329.png
# /kaggle/input/cityscapes-validation/segments/val/val247.png
# /kaggle/input/cityscapes-validation/segments/val/val446.png
# /kaggle/input/cityscapes-validation/segments/val/val110.png
# /kaggle/input/cityscapes-validation/segments/val/val33.png
# /kaggle/input/cityscapes-validation/segments/val/val395.png
# /kaggle/input/cityscapes-validation/segments/val/val72.png
# /kaggle/input/cityscapes-validation/segments/val/val399.png
# /kaggle/input/cityscapes-validation/segments/val/val41.png
# /kaggle/input/cityscapes-validation/segments/val/val27.png
# /kaggle/input/cityscapes-validation/segments/val/val453.png
# /kaggle/input/cityscapes-validation/segments/val/val169.png
# /kaggle/input/cityscapes-validation/segments/val/val123.png
# /kaggle/input/cityscapes-validation/segments/val/val474.png
# /kaggle/input/cityscapes-validation/segments/val/val113.png
# /kaggle/input/cityscapes-validation/segments/val/val93.png
# /kaggle/input/cityscapes-validation/segments/val/val48.png
# /kaggle/input/cityscapes-validation/segments/val/val298.png
# /kaggle/input/cityscapes-validation/segments/val/val390.png
# /kaggle/input/cityscapes-validation/segments/val/val352.png
# /kaggle/input/cityscapes-validation/segments/val/val193.png
# /kaggle/input/cityscapes-validation/segments/val/val206.png
# /kaggle/input/cityscapes-validation/segments/val/val358.png
# /kaggle/input/cityscapes-validation/segments/val/val97.png
# /kaggle/input/cityscapes-validation/segments/val/val288.png
# /kaggle/input/cityscapes-validation/segments/val/val198.png
# /kaggle/input/cityscapes-validation/segments/val/val357.png
# /kaggle/input/cityscapes-validation/segments/val/val37.png
# /kaggle/input/cityscapes-validation/segments/val/val164.png
# /kaggle/input/cityscapes-validation/segments/val/val142.png
# /kaggle/input/cityscapes-validation/segments/val/val301.png
# /kaggle/input/cityscapes-validation/segments/val/val266.png
# /kaggle/input/cityscapes-validation/segments/val/val212.png
# /kaggle/input/cityscapes-validation/segments/val/val244.png
# /kaggle/input/cityscapes-validation/segments/val/val177.png
# /kaggle/input/cityscapes-validation/segments/val/val45.png
# /kaggle/input/cityscapes-validation/segments/val/val394.png
# /kaggle/input/cityscapes-validation/segments/val/val175.png
# /kaggle/input/cityscapes-validation/segments/val/val323.png
# /kaggle/input/cityscapes-validation/segments/val/val69.png
# /kaggle/input/cityscapes-validation/segments/val/val463.png
# /kaggle/input/cityscapes-validation/segments/val/val199.png
# /kaggle/input/cityscapes-validation/segments/val/val479.png
# /kaggle/input/cityscapes-validation/segments/val/val4.png
# /kaggle/input/cityscapes-validation/segments/val/val249.png
# /kaggle/input/cityscapes-validation/segments/val/val442.png
# /kaggle/input/cityscapes-validation/segments/val/val63.png
# /kaggle/input/cityscapes-validation/segments/val/val408.png
# /kaggle/input/cityscapes-validation/segments/val/val320.png
# /kaggle/input/cityscapes-validation/segments/val/val73.png
# /kaggle/input/cityscapes-validation/segments/val/val376.png
# /kaggle/input/cityscapes-validation/segments/val/val174.png
# /kaggle/input/cityscapes-validation/segments/val/val316.png
# /kaggle/input/cityscapes-validation/segments/val/val351.png
# /kaggle/input/cityscapes-validation/segments/val/val456.png
# /kaggle/input/cityscapes-validation/segments/val/val6.png
# /kaggle/input/cityscapes-validation/segments/val/val430.png
# /kaggle/input/cityscapes-validation/segments/val/val173.png
# /kaggle/input/cityscapes-validation/segments/val/val3.png
# /kaggle/input/cityscapes-validation/segments/val/val306.png
# /kaggle/input/cityscapes-validation/segments/val/val248.png
# /kaggle/input/cityscapes-validation/segments/val/val260.png
# /kaggle/input/cityscapes-validation/segments/val/val53.png
# /kaggle/input/cityscapes-validation/segments/val/val425.png
# /kaggle/input/cityscapes-validation/segments/val/val488.png
# /kaggle/input/cityscapes-validation/segments/val/val16.png
# /kaggle/input/cityscapes-validation/segments/val/val397.png
# /kaggle/input/cityscapes-validation/segments/val/val467.png
# /kaggle/input/cityscapes-validation/segments/val/val25.png
# /kaggle/input/cityscapes-validation/segments/val/val149.png
# /kaggle/input/cityscapes-validation/segments/val/val232.png
# /kaggle/input/cityscapes-validation/segments/val/val35.png
# /kaggle/input/cityscapes-validation/segments/val/val365.png
# /kaggle/input/cityscapes-validation/segments/val/val452.png
# /kaggle/input/cityscapes-validation/segments/val/val80.png
# /kaggle/input/cityscapes-validation/segments/val/val490.png
# /kaggle/input/cityscapes-validation/segments/val/val292.png
# /kaggle/input/cityscapes-validation/segments/val/val345.png
# /kaggle/input/cityscapes-validation/segments/val/val252.png
# /kaggle/input/cityscapes-validation/segments/val/val356.png
# /kaggle/input/cityscapes-validation/segments/val/val433.png
# /kaggle/input/cityscapes-validation/segments/val/val422.png
# /kaggle/input/cityscapes-validation/segments/val/val402.png
# /kaggle/input/cityscapes-validation/segments/val/val133.png
# /kaggle/input/cityscapes-validation/segments/val/val236.png
# /kaggle/input/cityscapes-validation/segments/val/val254.png
# /kaggle/input/cityscapes-validation/segments/val/val289.png
# /kaggle/input/cityscapes-validation/segments/val/val360.png
# /kaggle/input/cityscapes-validation/segments/val/val196.png
# /kaggle/input/cityscapes-validation/segments/val/val267.png
# /kaggle/input/cityscapes-validation/segments/val/val172.png
# /kaggle/input/cityscapes-validation/segments/val/val98.png
# /kaggle/input/cityscapes-validation/segments/val/val128.png
# /kaggle/input/cityscapes-validation/segments/val/val147.png
# /kaggle/input/cityscapes-validation/segments/val/val392.png
# /kaggle/input/cityscapes-validation/segments/val/val473.png
# /kaggle/input/cityscapes-validation/segments/val/val2.png
# /kaggle/input/cityscapes-validation/segments/val/val271.png
# /kaggle/input/cityscapes-validation/segments/val/val89.png
# /kaggle/input/cityscapes-validation/segments/val/val9.png
# /kaggle/input/cityscapes-validation/segments/val/val141.png
# /kaggle/input/cityscapes-validation/segments/val/val168.png
# /kaggle/input/cityscapes-validation/segments/val/val109.png
# /kaggle/input/cityscapes-validation/segments/val/val401.png
# /kaggle/input/cityscapes-validation/segments/val/val114.png
# /kaggle/input/cityscapes-validation/segments/val/val162.png
# /kaggle/input/cityscapes-validation/segments/val/val62.png
# /kaggle/input/cityscapes-validation/segments/val/val204.png
# /kaggle/input/cityscapes-validation/segments/val/val344.png
# /kaggle/input/cityscapes-validation/segments/val/val156.png
# /kaggle/input/cityscapes-validation/segments/val/val487.png
# /kaggle/input/cityscapes-validation/segments/val/val381.png
# /kaggle/input/cityscapes-validation/segments/val/val205.png
# /kaggle/input/cityscapes-validation/segments/val/val495.png
# /kaggle/input/cityscapes-validation/segments/val/val498.png
# /kaggle/input/cityscapes-validation/segments/val/val434.png
# /kaggle/input/cityscapes-validation/segments/val/val431.png
# /kaggle/input/cityscapes-validation/segments/val/val5.png
# /kaggle/input/cityscapes-validation/segments/val/val440.png
# /kaggle/input/cityscapes-validation/segments/val/val242.png
# /kaggle/input/cityscapes-validation/segments/val/val216.png
# /kaggle/input/cityscapes-validation/segments/val/val191.png
# /kaggle/input/cityscapes-validation/segments/val/val454.png
# /kaggle/input/cityscapes-validation/segments/val/val335.png
# /kaggle/input/cityscapes-validation/segments/val/val274.png
# /kaggle/input/cityscapes-validation/segments/val/val322.png
# /kaggle/input/cityscapes-validation/segments/val/val251.png
# /kaggle/input/cityscapes-validation/segments/val/val457.png
# /kaggle/input/cityscapes-validation/segments/val/val450.png
# /kaggle/input/cityscapes-validation/segments/val/val416.png
# /kaggle/input/cityscapes-validation/segments/val/val287.png
# /kaggle/input/cityscapes-validation/segments/val/val92.png
# /kaggle/input/cityscapes-validation/segments/val/val50.png
# /kaggle/input/cityscapes-validation/segments/val/val82.png
# /kaggle/input/cityscapes-validation/segments/val/val22.png
# /kaggle/input/cityscapes-validation/segments/val/val202.png
# /kaggle/input/cityscapes-validation/segments/val/val188.png
# /kaggle/input/cityscapes-validation/segments/val/val427.png
# /kaggle/input/cityscapes-validation/segments/val/val152.png
# /kaggle/input/cityscapes-validation/segments/val/val19.png

# %%
# %cd /kaggle/working
# !rm -rf Drivablearea-lanedetectionusingTwinLiteNet
# !git clone https://github.com/taz2419/Drivablearea-lanedetectionusingTwinLiteNet.git
# %cd Drivablearea-lanedetectionusingTwinLiteNet
# Out:
# /kaggle/working
# Cloning into 'Drivablearea-lanedetectionusingTwinLiteNet'...
# remote: Enumerating objects: 314, done.
# remote: Counting objects: 100% (143/143), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 314 (delta 96), reused 95 (delta 56), pack-reused 171 (from 2)
# Receiving objects: 100% (314/314), 6.34 MiB | 26.71 MiB/s, done.
# Resolving deltas: 100% (150/150), done.
# /kaggle/working/Drivablearea-lanedetectionusingTwinLiteNet

# %%
# !ls -la datasets/
# !cat datasets/custom_dataset.py | head -20
# Out:
# total 16
# drwxr-xr-x 2 root root 4096 Oct 26 21:18 .
# drwxr-xr-x 8 root root 4096 Oct 26 21:18 ..
# -rw-r--r-- 1 root root 5021 Oct 26 21:18 custom_dataset.py
# import os
# from glob import glob
# from typing import List, Tuple, Sequence, Optional
# from PIL import Image
# import numpy as np
# import torch
# from torch.utils.data import Dataset
#
# def _parse_ids(ids: Optional[Sequence[int] | str], default: Sequence[int]) -> List[int]:
#     if ids is None:
#         return list(default)
#     if isinstance(ids, str):
#         ids = ids.strip()
#         if not ids:
#             return []
#         return [int(x) for x in ids.split(",")]
#     return [int(x) for x in ids]
#
# class CustomTwinLiteDataset(Dataset):
#     """

# %%
# !touch datasets/__init__.py

# %%
# %env DA_IDS=0
# %env LL_IDS=
# !python val.py --weight "pretrained/best.pth" --num_workers 2 --batch_size 16
# Out:
# env: DA_IDS=0
# env: LL_IDS=
# ==================================================
# Validation Results:
# ==================================================
#
# Drivable Area Segmentation:
#   IoU: 0.7024
#   Pixel Accuracy: 0.8852
