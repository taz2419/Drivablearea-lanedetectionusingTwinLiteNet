# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/bdd100validationonly/bdd100k_validation_only/images/val/b5764fb7-c47fa3ec.jpg
# /kaggle/input/bdd100validationonly/bdd100k_validation_only/images/val/b539383c-b57307bc.jpg
# /kaggle/input/bdd100validationonly/bdd100k_validation_only/images/val/c0a7a9dc-497459f0.jpg
# /kaggle/input/bdd100validationonly/bdd100k_validation_only/images/val/c4a19ba6-e706bdc2.jpg
# /kaggle/input/bdd100validationonly/bdd100k_validation_only/images/val/c0e6d0ec-17a4eb38.jpg
# /kaggle/input/bdd100validationonly/bdd100k_validation_only/images/val/b5e1a441-3bc3277c.jpg
# /kaggle/input/bdd100validationonly/bdd100k_validation_only/images/val/b5191523-af1c9a30.jpg
# /kaggle/input/bdd100validationonly/bdd100k_validation_only/images/val/bfc06497-fc2b4581.jpg
# /kaggle/input/bdd100validationonly/bdd100k_validation_only/images/val/b82f91d7-808670c6.jpg
# /kaggle/input/bdd100validationonly/bdd100k_validation_only/images/val/c9dc96aa-01dec7af.jpg
# ...

# %%
# !git clone https://github.com/taz2419/Drivablearea-lanedetectionusingTwinLiteNet.git
# Out:
# Cloning into 'Drivablearea-lanedetectionusingTwinLiteNet'...
# remote: Enumerating objects: 290, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 290 (delta 82), reused 79 (delta 50), pack-reused 171 (from 2)
# Receiving objects: 100% (290/290), 6.33 MiB | 48.38 MiB/s, done.
# Resolving deltas: 100% (136/136), done.

# %%
# %cd Drivablearea-lanedetectionusingTwinLiteNet
# %pip install --quiet -r requirements.txt || pip install --quiet yacs webcolors
# Out:
# /kaggle/working/Drivablearea-lanedetectionusingTwinLiteNet/Drivablearea-lanedetectionusingTwinLiteNet/Drivablearea-lanedetectionusingTwinLiteNet/Drivablearea-lanedetectionusingTwinLiteNet/Drivablearea-lanedetectionusingTwinLiteNet/Drivablearea-lanedetectionusingTwinLiteNet
# Note: you may need to restart the kernel to use updated packages.

# %%
# %env BDD100K_ROOT=/kaggle/input/bdd100validationonly/bdd100k_validation_only
# !python val.py --weight "pretrained/best.pth" --num_workers 2 --batch_size 16
# Out:
# env: BDD100K_ROOT=/kaggle/input/bdd100validationonly/bdd100k_validation_only
# Using device: cuda
# GPU: Tesla T4
# Available GPU memory: 15.83 GB
# Building model...
# Loading weights from pretrained/best.pth
# ✓ Successfully loaded weights
# Total parameters: 439,633
# Loading validation dataset...
# Loaded 10000 images from /kaggle/input/bdd100validationonly/bdd100k_validation_only/images/val
# Total validation samples: 10000
# Starting validation...
# 100%|█████████████████████████████████████████| 625/625 [04:43<00:00,  2.20it/s]
#
# ...
# Validation Results:
# ...
#
# Drivable Area Segmentation:
#   IoU: 0.8580
#   Pixel Accuracy: 0.9737
#
# Lane Line Segmentation:
#   IoU: 0.3119
#   Pixel Accuracy: 0.9896
# ...
